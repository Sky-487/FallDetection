# %%
from tinyml import *

# %%
Model = CreateModel()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 32)                23072
#
#  dense_7 (Dense)             (None, 16)                528
#
#  dense_8 (Dense)             (None, 2)                 34
#
# ...
# Total params: 23,634
# Trainable params: 23,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
x, y = ReadTrainingData()
TrainModel(Model, x, y)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 0s 132ms/step - loss: 1.8130 - categorical_accuracy: 0.5455 - val_loss: 3.5794 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/200
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6902 - categorical_accuracy: 0.6364 - val_loss: 4.3992 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5427 - categorical_accuracy: 0.6364 - val_loss: 5.2520 - val_categorical_accuracy: 0.0000e+00
# Epoch 4/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5566 - categorical_accuracy: 0.6818 - val_loss: 5.8926 - val_categorical_accuracy: 0.0000e+00
# Epoch 5/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5704 - categorical_accuracy: 0.5909 - val_loss: 6.3069 - val_categorical_accuracy: 0.0000e+00
# Epoch 6/200
# ...

# %%
ConvertModel(Model)

# %%
tfModel=ConvertModel(Model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Hans\AppData\Local\Temp\tmp1j7oi13b\assets
# INFO:tensorflow:Assets written to: C:\Users\Hans\AppData\Local\Temp\tmp1j7oi13b\assets

# %%
tfModel=ConvertModel(Model)
Hex2H(tfModel, "model")
